# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\riddh\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\riddh\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\riddh\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 2.6 MB/s eta 0:00:05
#    --- ------------------------------------ 1.0/11.0 MB 2.3 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.0 MB 2.7 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.0 MB 2.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.1/11.0 MB 2.9 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/11.0 MB 3.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.7/11.0 MB 3.1 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.0 MB 3.3 MB/s eta 0:00:02
#    ------------------------ --------------- 6.8/11.0 MB 3.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.9/11.0 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/11.0 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 3.8 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed pandas-2.3.3 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np  # numpy is not necessary for pandas, but we will use some np code in this example
# in general it's good practice to import all pacakages at the beginning

# %%
# series - list, np.array

# %%
mylist=[1,2,3,4]
array=np.random.randint(10,20,4)

# %%
print(mylist)
print(array)
# Out:
# [1, 2, 3, 4]
# [15 19 19 13]

# %%
s1=pd.Series(mylist)
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s2=pd.Series(array)
s2
# Out:
# 0    15
# 1    19
# 2    19
# 3    13
# dtype: int64

# %%
# first let's look at series - think of this as a single column of a spreadsheet
# each entry in a series corresponds to an individual row in the spreadsheet
# we can create a series by converting a list, or numpy array

mylist = [5.4,6.1,1.7,99.8]
myarray = np.array(mylist)

# %%
a=pd.Series(mylist)
a
# Out:
# 0     5.4
# 1     6.1
# 2     1.7
# 3    99.8
# dtype: float64

# %%
myseries1 = pd.Series(data=mylist)
print(myseries1)
myseries2 = pd.Series(data=myarray)
print(myseries2)
# Out:
# 0     5.4
# 1     6.1
# 2     1.7
# 3    99.8
# dtype: float64
# 0     5.4
# 1     6.1
# 2     1.7
# 3    99.8
# dtype: float64

# %%
# we access individual entries the same way as with lists and arrays
print(myseries2[2:3])
# Out:
# 2    1.7
# dtype: float64

# %%
# we can add labels to the entries of a series

mylabels = ['first','second','third','fourth']
myseries3 = pd.Series(data=mylist,index=mylabels)
print(myseries3)
# Out:
# first      5.4
# second     6.1
# third      1.7
# fourth    99.8
# dtype: float64

# %%
print(myseries3["second":"third"])
print(myseries3[1:3])
# Out:
# second    6.1
# third     1.7
# dtype: float64
# second    6.1
# third     1.7
# dtype: float64

# %%
# we need not be explicit about the entries of pd.Series
myseries4 = pd.Series(mylabels,mylist)
print(myseries4)
# Out:
# 5.4      first
# 6.1     second
# 1.7      third
# 99.8    fourth
# dtype: object

# %%
# we can also access entries using the index labels
print(myseries3['first':'third'])
# Out:
# first     5.4
# second    6.1
# third     1.7
# dtype: float64

# %%
myseries4[5.4]
# Out:
# 'first'

# %%
# myseries5
myseries3
# Out:
# first      5.4
# second     6.1
# third      1.7
# fourth    99.8
# dtype: float64

# %%
name="tanishka "
surname="ruhela"
name+surname
# Out:
# 'tanishka ruhela'

# %%
# we can do math on series
myseries5 = pd.Series([5.5,1.1,8.8,1.6],['first','second','third','fourth'])
print(myseries5)
print('')
print(myseries5+myseries3)
# Out:
# first     5.5
# second    1.1
# third     8.8
# fourth    1.6
# dtype: float64
#
# first      10.9
# second      7.2
# third      10.5
# fourth    101.4
# dtype: float64

# %%
# concatenate 1,2 - 12

# %%
print(myseries3)
print()
print(myseries5)
# Out:
# first      5.4
# second     6.1
# third      1.7
# fourth    99.8
# dtype: float64
#
# first     5.5
# second    1.1
# third     8.8
# fourth    1.6
# dtype: float64

# %%
# we can combine series to create a dataframe using the concat function

df1 = pd.concat([myseries3,myseries5],axis=1)
df1
# Out:
#            0    1
# first    5.4  5.5
# second   6.1  1.1
# third    1.7  8.8
# fourth  99.8  1.6

# %%
# we can create a new dataframe
df2 = pd.DataFrame(np.arange(1,26).reshape(5,5),index=['a','b','c','d','e'],columns=['p','q','r','s','t'])
df2
# Out:
#     p   q   r   s   t
# a   1   2   3   4   5
# b   6   7   8   9  10
# c  11  12  13  14  15
# d  16  17  18  19  20
# e  21  22  23  24  25

# %%
dict = {
    "p":[1,6,11,16,21],
    "q":[2,7,12,17,22],
    "r":[3,8,13,18,23],
    "s":[4,9,14,19,24],
    "t":[5,10,15,20,25]
}
pd.DataFrame(data=dict,index=['a','b','c','d','e'])
# Out:
#     p   q   r   s   t
# a   1   2   3   4   5
# b   6   7   8   9  10
# c  11  12  13  14  15
# d  16  17  18  19  20
# e  21  22  23  24  25

# %%
# lets give labels to rows and columns
df3 = pd.DataFrame(np.random.randn(5,5),index=['first row','second row','third row',
                                               'fourth row','fifth row'],
                   columns=['first col','second col','third col','fourth col','fifth col'])
df3
# Out:
#             first col  second col  third col  fourth col  fifth col
# first row   -0.973608   -0.181292  -0.448298   -0.184355  -0.065197
# second row  -1.273606   -0.904502  -0.563436    1.397200   0.187210
# third row    2.145595    2.477128   0.083477    0.041589  -0.174509
# fourth row  -0.737812   -0.917748  -0.162769    1.548283  -1.024416
# fifth row    0.804843    0.410718  -0.168196   -0.376661  -1.120841

# %%
df3.columns
# Out:
# Index(['first col', 'second col', 'third col', 'fourth col', 'fifth col'], dtype='object')

# %%
df3[['first col',  'third col',  'fifth col']]
# Out:
#             first col  third col  fifth col
# first row   -0.973608  -0.448298  -0.065197
# second row  -1.273606  -0.563436   0.187210
# third row    2.145595   0.083477  -0.174509
# fourth row  -0.737812  -0.162769  -1.024416
# fifth row    0.804843  -0.168196  -1.120841

# %%
df3.loc[['second row','fourth row'],['third col','first col']]
# Out:
#             third col  first col
# second row  -0.563436  -1.273606
# fourth row  -0.162769  -0.737812

# %%
df3
# Out:
#             first col  second col  third col  fourth col  fifth col
# first row   -0.973608   -0.181292  -0.448298   -0.184355  -0.065197
# second row  -1.273606   -0.904502  -0.563436    1.397200   0.187210
# third row    2.145595    2.477128   0.083477    0.041589  -0.174509
# fourth row  -0.737812   -0.917748  -0.162769    1.548283  -1.024416
# fifth row    0.804843    0.410718  -0.168196   -0.376661  -1.120841

# %%
df3.iloc[0:2,3:]
# Out:
#             fourth col  fifth col
# first row    -0.184355  -0.065197
# second row    1.397200   0.187210

# %%
df3.tail(2)
# Out:
#             first col  second col  third col  fourth col  fifth col
# fourth row  -0.737812   -0.917748  -0.162769    1.548283  -1.024416
# fifth row    0.804843    0.410718  -0.168196   -0.376661  -1.120841

# %%
df3.head()
# Out:
#             first col  second col  third col  fourth col  fifth col
# first row   -0.973608   -0.181292  -0.448298   -0.184355  -0.065197
# second row  -1.273606   -0.904502  -0.563436    1.397200   0.187210
# third row    2.145595    2.477128   0.083477    0.041589  -0.174509
# fourth row  -0.737812   -0.917748  -0.162769    1.548283  -1.024416
# fifth row    0.804843    0.410718  -0.168196   -0.376661  -1.120841

# %%
# we can access individual series in a data frame
df3['second col']
#print('')
#df3[['third col','first col']]
# Out:
# first row    -0.181292
# second row   -0.904502
# third row     2.477128
# fourth row   -0.917748
# fifth row     0.410718
# Name: second col, dtype: float64

# %%
# we can access rows of a dataframe
df3.loc['fourth row']
# Out:
# first col    -0.737812
# second col   -0.917748
# third col    -0.162769
# fourth col    1.548283
# fifth col    -1.024416
# Name: fourth row, dtype: float64

# %%
df3.loc[['fourth row','third row'],['second col','first col']]
# Out:
#             second col  first col
# fourth row   -0.917748  -0.737812
# third row     2.477128   2.145595

# %%
df3
# Out:
#             first col  second col  third col  fourth col  fifth col
# first row   -0.973608   -0.181292  -0.448298   -0.184355  -0.065197
# second row  -1.273606   -0.904502  -0.563436    1.397200   0.187210
# third row    2.145595    2.477128   0.083477    0.041589  -0.174509
# fourth row  -0.737812   -0.917748  -0.162769    1.548283  -1.024416
# fifth row    0.804843    0.410718  -0.168196   -0.376661  -1.120841

# %%
df3.iloc[1:,3:]
# Out:
#             fourth col  fifth col
# second row    1.397200   0.187210
# third row     0.041589  -0.174509
# fourth row    1.548283  -1.024416
# fifth row    -0.376661  -1.120841

# %%
df3
# Out:
#             first col  second col  third col  fourth col  fifth col
# first row   -0.973608   -0.181292  -0.448298   -0.184355  -0.065197
# second row  -1.273606   -0.904502  -0.563436    1.397200   0.187210
# third row    2.145595    2.477128   0.083477    0.041589  -0.174509
# fourth row  -0.737812   -0.917748  -0.162769    1.548283  -1.024416
# fifth row    0.804843    0.410718  -0.168196   -0.376661  -1.120841

# %%
df3[(df3['second col'] < 0 )   ]
# Out:
#             first col  second col  third col  fourth col  fifth col
# first row   -0.973608   -0.181292  -0.448298   -0.184355  -0.065197
# second row  -1.273606   -0.904502  -0.563436    1.397200   0.187210
# fourth row  -0.737812   -0.917748  -0.162769    1.548283  -1.024416

# %%
df3.iloc[4:,2:]
# Out:
#            third col  fourth col  fifth col
# fifth row  -0.168196   -0.376661  -1.120841

# %%
df3.loc[['fourth row','first row'],['second col','third col']]
# Out:
#             second col  third col
# fourth row   -0.917748  -0.162769
# first row    -0.181292  -0.448298

# %%
df3
# Out:
#             first col  second col  third col  fourth col  fifth col
# first row   -0.973608   -0.181292  -0.448298   -0.184355  -0.065197
# second row  -1.273606   -0.904502  -0.563436    1.397200   0.187210
# third row    2.145595    2.477128   0.083477    0.041589  -0.174509
# fourth row  -0.737812   -0.917748  -0.162769    1.548283  -1.024416
# fifth row    0.804843    0.410718  -0.168196   -0.376661  -1.120841

# %%
# we can use logical indexing for dataframes just like for numpy arrays
df3[df3>1]
# Out:
#             first col  second col  third col  fourth col  fifth col
# first row         NaN         NaN        NaN         NaN        NaN
# second row        NaN         NaN        NaN    1.397200        NaN
# third row    2.145595    2.477128        NaN         NaN        NaN
# fourth row        NaN         NaN        NaN    1.548283        NaN
# fifth row         NaN         NaN        NaN         NaN        NaN

# %%
df3
# Out:
#             first col  second col  third col  fourth col  fifth col
# first row   -0.973608   -0.181292  -0.448298   -0.184355  -0.065197
# second row  -1.273606   -0.904502  -0.563436    1.397200   0.187210
# third row    2.145595    2.477128   0.083477    0.041589  -0.174509
# fourth row  -0.737812   -0.917748  -0.162769    1.548283  -1.024416
# fifth row    0.804843    0.410718  -0.168196   -0.376661  -1.120841

# %%
# df3['sixth col']=['This','is','a','new','col']
df3['abc']=['Yet','another','new','col',np.NaN]
df3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-82-3437293960.py in <cell line: 0>()
#       1 # df3['sixth col']=['This','is','a','new','col']
# ----> 2 df3['abc']=['Yet','another','new','col',np.NaN]
#       3 df3
#
# /usr/local/lib/python3.11/dist-packages/numpy/__init__.py in __getattr__(attr)
#     395
#     396         if attr in __expired_attributes__:
# --> 397             raise AttributeError(
#     398                 f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     399                 f"{__expired_attributes__[attr]}"
#
# AttributeError: `np.NaN` was removed in the NumPy 2.0 release. Use `np.nan` instead.

# %%
# we can add columns to a dataframe
df3['seventh col'] = np.random.randn(5,1)
df3
# Out:
#             first col  second col  third col  fourth col  fifth col  \
# first row   -0.973608   -0.181292  -0.448298   -0.184355  -0.065197
# second row  -1.273606   -0.904502  -0.563436    1.397200   0.187210
# third row    2.145595    2.477128   0.083477    0.041589  -0.174509
# fourth row  -0.737812   -0.917748  -0.162769    1.548283  -1.024416
# fifth row    0.804843    0.410718  -0.168196   -0.376661  -1.120841
#
#             seventh col
# first row     -1.142019
# second row     1.118847
# third row      2.009804
# fourth row     1.849422
# fifth row     -1.883223

# %%
# we can remove columns or rows from a dataframe
# Method 1
df3.drop('abc',axis=1,inplace = True)
# df3.drop('second col',axis = 1,inplace = True)
df3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-84-109797455.py in <cell line: 0>()
#       1 # we can remove columns or rows from a dataframe
#       2 # Method 1
# ----> 3 df3.drop('abc',axis=1,inplace = True)
#       4 # df3.drop('second col',axis = 1,inplace = True)
#       5 df3
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['abc'] not found in axis"

# %%
#Method 2
df3.drop('fifth row',axis=0,inplace=True)

# %%
df3
# Out:
#             first col  second col  third col  fourth col  fifth col  \
# first row   -0.973608   -0.181292  -0.448298   -0.184355  -0.065197
# second row  -1.273606   -0.904502  -0.563436    1.397200   0.187210
# third row    2.145595    2.477128   0.083477    0.041589  -0.174509
# fourth row  -0.737812   -0.917748  -0.162769    1.548283  -1.024416
#
#             seventh col
# first row     -1.142019
# second row     1.118847
# third row      2.009804
# fourth row     1.849422

# %%
df3.drop('second col',axis=1)

# %%
df3

# %%
df4 = df3.drop(['second col'],axis=1)
df4

# %%
df5 = df3.drop('second row',axis=0)
df5

# %%
df3=df3.drop('second row',axis=0)
df3

# %%
# Pandas - Series, DataFrame

# %%
s=pd.Series([1,2,3,4],index=['a','b','c','d'])

# %%
s[1:3]

# %%
df5.iloc[1:3,1:3]

# %%
df5

# %%
df3[df3<1]

# %%
df=pd.DataFrame(np.random.randint(5,35,(5,6)))

# %%
df

# %%
# - Give me numbers greater than 25 and it will be even number.
df[(df>25) & (df%2==0)]

# %%
df[(df>0.5)]

# %%
df5.drop('first row',axis=0,inplace=True)

# %%
df5

# %%
# df.reset_index(drop='First')
df[0].reset_index()

# %%
df.reset_index(drop=True)

# %%
# we can remove a dataframe's index labels
df5.reset_index(inplace=True)

# %%
df5

# %%
df5.reset_index(inplace=True)
df5

# %%
s=['one','two','three','four','five']

# %%
df['Level_1']=s
df.set_index('Level_1')

# %%
df5.drop('level_0',axis=1)

# %%
df5.set_index('second col')

# %%
# we can assign new names to the index
df5['new index'] = ['This','is a new','row']
df5.set_index('new index',drop=True)

# %%
df5

# %%
df5.set_index('new index',inplace=True)
df5

# %%
df5.reset_index()

# %% [markdown]
# ## Pandas Lecture 2

# %% [markdown]
# # Combining data frames
#
# The ways dataframes are combined in pandas is similar to SQL
#
# We will examine 3 methods for combining dataframes
#
# 1. concat
# 2. join
# 3. merge

# %%
df7 = pd.DataFrame({"customer":['101','102','103','104'],
                    'category': ['cat2','cat2','cat1','cat3'],
                    'important': ['yes','no','yes','yes'],
                    'sales': [123,52,214,663]},index=[0,1,2,3])

df8 = pd.DataFrame({"customer":['101','103','104','105'],
                    'color': ['yellow','green','green','blue'],
                    'distance': [12,9,44,21],
                    'sales': [123,214,663,331]},index=[4,5,6,7])

#list of tuples
df7
# Out:
#   customer category important  sales
# 0      101     cat2       yes    123
# 1      102     cat2        no     52
# 2      103     cat1       yes    214
# 3      104     cat3       yes    663

# %%
df8

# %%
df7

# %%
pd.concat([df7,df8],axis=1,sort=True)

# %%
pd.concat([df7,df8],axis=1,sort=False)

# %%
pd.concat([df7,df8],axis=1,sort=False)

# %% [markdown]
# # Merge and Join
#
# Merge combines dataframes using a column's values to identify common entries
#
# Join combines dataframes using the index to identify common entries

# %%
df7

# %%
df8

# %%
pd.merge(df7,df8,how='left',on=['customer','sales']) # outer merge is union of on

# %%
pd.merge(df7,df8,how='inner',on=['customer','sales'],) # inner merge is intersection of on

# %%
pd.merge(df7,df8,'right','customer') # left merge is just first on, but all columns ... right is second

# %%
pd.merge(df7,df8,'outer','customer') # left merge is just first on, but all columns ... right is second

# %%
df9 = pd.DataFrame({'Q1': [101,102,103],
                    'Q2': [201,202,203]},
                   index=['I0','I1','I2'])

df10 = pd.DataFrame({'Q3': [301,302,303],
                    'Q4': [401,402,403]},
                   index=['I0','I2','I3'])

# %%
print(df9)
print('')
df10

# %%
# join behaves just like merge,
# except instead of using the values of one of the columns
# to combine data frames, it uses the index labels
df9.join(df10,how='left') # outer, inner, left, and right work the same as merge

# %%
df8

# %%
print(df8['color'])
print(df8.color.value_counts())

# %%
df8.color.unique()

# - unique - gives all unique values
# - unique() - output - np.array
# - nunique() - number of unique values - len(df.color.unique())

# %%
df8.color.value_counts().reset_index()
# output - series

# %%
df8.color.value_counts()

# %%
df8['color'].unique()

# %%
# let's now go over a few more basic functialities of pandas

df8['color'].unique()

# %%
df8['color'].value_counts()

# %%
df9

# %%
df9.Q1.mode()[0]

# %%
df9.mean(axis=0)

# %%
df8.columns

# %%
df8['color']

# %%
df8

# %%
# -- rows having color as green
df8[(df8.color=='green')]

# %%
# Rows having green and distance even
df8[(df8.color=='green') & (df8.distance%2==0)][['customer','color']]

# %%
df8[['color','distance']]

# %%
df8[(df8['color']=='green') & (df8['distance']<10)]

# %%
df8

# %%
df8[(df8['color']=='green') & (df8.distance<10)]

# %%
df8.sales.mean()

# %%
print(df8['sales'].sum())
# print(df8['distance'].min()) #
df8.distance.min()

# %%
df8['profit']=df8.sales*0.2

# %%
df8

# %%
def profit(s):
    return s*20/100

# %%
df8['profit1'] = df8.sales.apply(profit)

# %%
df8

# %%
df8['discount']=df8.profit.apply(lambda x:x/2)

# %%
df8

# %%
def profit(s):
    return s*0.5 # 50% markup...

# %%
df8['sales']

# %%
df8['sales'].apply(profit)

# %%
df8['color'].apply(len)

# %%
df11 = df8[['distance','sales']]
df11

# df11

# %%
df11.applymap(profit)

# %%
df11

# %%
def col_sum(abc):
    return sum(abc)
df11.apply(col_sum)

# %%
df8

# %%
df8.columns

# %%
df8

# %%
df8.sort_values(by=['sales'],ascending=False,inplace=True)
df8

# %%
df8

# %%
# if some series has multiple of the same value then we can group all the unique entries together
mydict = {'customer': ['Customer 1','Customer 1','Customer2','Customer2','Customer3','Customer3'],
          'product1': [1.1,2.1,3.8,4.2,5.5,6.9],
          'product2': [8.2,9.1,11.1,5.2,44.66,983]}
df6 = pd.DataFrame(mydict,index=['Purchase 1','Purchase 2','Purchase 3','Purchase 4','Purchase 5','Purchase 6'])
df6
# Out:
#               customer  product1  product2
# Purchase 1  Customer 1       1.1      8.20
# Purchase 2  Customer 1       2.1      9.10
# Purchase 3   Customer2       3.8     11.10
# Purchase 4   Customer2       4.2      5.20
# Purchase 5   Customer3       5.5     44.66
# Purchase 6   Customer3       6.9    983.00

# %%
df6.groupby('customer').mean()
# Out:
#             product1  product2
# customer
# Customer 1       1.6      8.65
# Customer2        4.0      8.15
# Customer3        6.2    513.83

# %%
df8
# Out:
#   customer   color  distance  sales
# 4      101  yellow        12    123
# 5      103   green         9    214
# 6      104   green        44    663
# 7      105    blue        21    331

# %%
df8.isnull().sum()
# Out:
# customer    0
# color       0
# distance    0
# sales       0
# dtype: int64

# %% [markdown]
# ## Working with a CSV File

# %%
cs=pd.read_csv("/content/Car_sales.csv")
cs
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# 1      Passenger               28.40          3.2       225.0      108.1
# 2      Passenger                 NaN          3.2       225.0      106.9
# 3      Passenger               42.00          3.5       210.0      114.6
# 4      Passenger               23.99          1.8       150.0      102.6
# ..           ...                 ...          ...         ...        ...
# 152    Passenger               24.40          1.9       160.0      100.5
# 153    Passenger               27.50          2.4       168.0      104.9
# 154    Passenger               28.80          2.4       168.0      104.9
# 155    Passenger               45.50          2.3       236.0      104.9
# 156    Passenger               36.00          2.9       201.0      109.9
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0     67.3   172.4        2.639           13.2             28.0      2/2/2012
# 1     70.3   192.9        3.517           17.2             25.0      6/3/2011
# 2     70.6   192.0        3.470           17.2             26.0      1/4/2012
# 3     71.4   196.6        3.850           18.0             22.0     3/10/2011
# 4     68.2   178.0        2.998           16.4             27.0     10/8/2011
# ..     ...     ...          ...            ...              ...           ...
# 152   67.6   176.6        3.042           15.8             25.0     9/21/2011
# 153   69.3   185.9        3.208           17.9             25.0    11/24/2012
# 154   69.3   186.2        3.259           17.9             25.0     6/25/2011
# 155   71.5   185.7        3.601           18.5             23.0     4/26/2011
# 156   72.1   189.8        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 0            58.280150
# 1            91.370778
# 2                  NaN
# 3            91.389779
# 4            62.777639
# ..                 ...
# 152          66.498812
# 153          70.654495
# 154          71.155978
# 155         101.623357
# 156          85.735655
#
# [157 rows x 16 columns]

# %%
cs.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
# 2        3.470           17.2             26.0      1/4/2012
# 3        3.850           18.0             22.0     3/10/2011
# 4        2.998           16.4             27.0     10/8/2011
#
#    Power_perf_factor
# 0          58.280150
# 1          91.370778
# 2                NaN
# 3          91.389779
# 4          62.777639

# %%
cs.tail()
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 152        Volvo   V40               3.545                  NaN    Passenger
# 153        Volvo   S70              15.245                  NaN    Passenger
# 154        Volvo   V70              17.531                  NaN    Passenger
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 152                24.4          1.9       160.0      100.5   67.6   176.6
# 153                27.5          2.4       168.0      104.9   69.3   185.9
# 154                28.8          2.4       168.0      104.9   69.3   186.2
# 155                45.5          2.3       236.0      104.9   71.5   185.7
# 156                36.0          2.9       201.0      109.9   72.1   189.8
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 152        3.042           15.8             25.0     9/21/2011
# 153        3.208           17.9             25.0    11/24/2012
# 154        3.259           17.9             25.0     6/25/2011
# 155        3.601           18.5             23.0     4/26/2011
# 156        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 152          66.498812
# 153          70.654495
# 154          71.155978
# 155         101.623357
# 156          85.735655

# %%
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
#  15  Power_perf_factor    155 non-null    float64
# dtypes: float64(12), object(4)
# memory usage: 19.8+ KB

# %%
cs.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# 25%       2.300000  149.500000  103.000000   68.400000  177.575000
# 50%       3.000000  177.500000  107.000000   70.550000  187.900000
# 75%       3.575000  215.000000  112.200000   73.425000  196.125000
# max       8.000000  450.000000  138.700000   79.900000  224.500000
#
#        Curb_weight  Fuel_capacity  Fuel_efficiency  Power_perf_factor
# count   155.000000     156.000000       154.000000         155.000000
# mean      3.378026      17.951923        23.844156          77.043591
# std       0.630502       3.887921         4.282706          25.142664
# min       1.895000      10.300000        15.000000          23.276272
# 25%       2.971000      15.800000        21.000000          60.407707
# 50%       3.342000      17.200000        24.000000          72.030917
# 75%       3.799500      19.575000        26.000000          89.414878
# max       5.572000      32.000000        45.000000         188.144323

# %%
cs.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv(r"C:Users/Dell/Downloads/weather.csv")   #read weather.csv data
df

# %%
import seaborn as sns
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# df.head(10)
#df.tail()
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#list of tuples
import pandas as pd
weather_data = [('1/1/2017', 32, 6, 'Rain'),
                ('1/2/2017', 35, 7, 'Sunny'),
                ('1/3/2017', 28, 2, 'Snow'),
                ('1/4/2017', 24, 7, 'Snow'),
                ('1/5/2017', 32, 4, 'Rain'),
                ('1/6/2017', 31, 2, 'Sunny')
               ]
df = pd.DataFrame(weather_data, columns=['day', 'temperature', 'windspeed', 'event'])
df

# %%
#get dimentions of the table

df.shape   #total number of rows and columns

# %%
df.head(2)

# %%
df.tail(4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#if you want to see initial some rows then use head command (default 5 rows)
df.head()

# %%
#if you want to see last few rows then use tail command (default last 5 rows will print)
df.tail()

# %%
#slicing
df[2:5]

# %%
df.columns   #print columns in a table

# %%
df.day      #print particular column data

df['day']

# %%
#another way of accessing column
df['day'] #df.day (both are same)

# %%
#get 2 or more columns
df[['day', 'event']]

# %%
# row with min temp
df[df.temperature==df.temperature.min()]

# %%
#get all temperatures
df['temperature']

# %%
#print max temperature
df['temperature'].max()

# %%
#print max temperature
df['temperature'].min()

# %%
#print max temperature
df['temperature'].describe()

# %%
# select rows which has maximum temperature
df[df.temperature == df.temperature.max()]

# %%
#select only day column which has maximum temperature
df[df.temperature == df.temperature.max()][['day','event']]
